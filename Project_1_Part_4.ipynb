# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedh897/Prediction-of-Product-Sales/blob/main/Project_1_Part_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Overview
# ![Screenshot 2026-03-04 192147.png](data:image/png;base64,...)

# %% [markdown]
# ## Load and Inspect Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          low fat         0.016047
# 1           DRC01         5.92          regular         0.019278
# 2           FDN15        17.50          low fat         0.016760
# 3           FDX07        19.20          regular         0.000000
# 4           NCD19         8.93          low fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
import numpy as np

# Identify columns with 'object' dtype which might contain 'Missing' placeholders
object_cols = df.select_dtypes(include='object').columns

for col in object_cols:
    if 'Missing' in df[col].unique():
        df[col] = df[col].replace('Missing', np.nan)

# Verify replacements by checking for nulls and unique values again
print('Null values after placeholder replacement:')
display(df.isnull().sum())
print('\nUnique values in Outlet_Size after replacement:')
print(df['Outlet_Size'].unique())
# Out:
# Null values after placeholder replacement:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64
# Unique values in Outlet_Size after replacement:
# ['Medium' nan 'High' 'Small']

# %% [markdown]
# ## Data Dictionary
#
# *   **Item_Identifier**: Unique product ID
# *   **Item_Weight**: Weight of product
# *   **Item_Fat_Content**: Whether the product is low fat or not
# *   **Item_Visibility**: The % of total display area of all products in a store allocated to the particular product
# *   **Item_Type**: The category to which the product belongs
# *   **Item_MRP**: Maximum Retail Price (list price) of the product
# *   **Outlet_Identifier**: Unique store ID
# *   **Outlet_Establishment_Year**: The year in which store was established
# *   **Outlet_Size**: The size of the store in terms of ground area
# *   **Outlet_Location_Type**: The type of city in which the store is located
# *   **Outlet_Type**: Whether the store is a grocery store or some type of supermarket
# *   **Item_Outlet_Sales**: Sales of the product in a particular store. This is the target variable.

# %% [markdown]
# ### Item_Identifier

# %% [markdown]
# Definition: Unique product ID

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

# For Item_Identifier, let's look at the number of unique identifiers
num_unique_items = df['Item_Identifier'].nunique()
print(f"Number of unique Item_Identifiers: {num_unique_items}")
# Out:
# Number of unique Item_Identifiers: 1559

# %% [markdown]
# ### Item_Weight

# %% [markdown]
# Definition: Weight of product

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Item_Weight'], kde=True, bins=30)
plt.title('Distribution of Item Weight')
plt.xlabel('Item Weight')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Item_Fat_Content

# %% [markdown]
# Definition: Whether the product is low fat or not

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x='Item_Fat_Content', data=df, palette='viridis')
plt.title('Distribution of Item Fat Content')
plt.xlabel('Item Fat Content')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_4591/3675621511.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Item_Fat_Content', data=df, palette='viridis')

# %% [markdown]
# ### Item_Visibility

# %% [markdown]
# Definition: The % of total display area of all products in a store allocated to the particular product

# %% [markdown]
# ### Item_Type

# %% [markdown]
# Definition: The category to which the product belongs

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Item_Type', data=df, palette='Spectral')
plt.title('Distribution of Item Type')
plt.xlabel('Item Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3847071920.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Item_Type', data=df, palette='Spectral')

# %% [markdown]
# ### Item_MRP

# %% [markdown]
# Definition: Maximum Retail Price (list price) of the product

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Item_MRP'], kde=True, bins=30)
plt.title('Distribution of Item MRP (Maximum Retail Price)')
plt.xlabel('Item MRP')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Outlet_Identifier

# %% [markdown]
# Definition: Unique store ID

# %%
num_unique_outlets = df['Outlet_Identifier'].nunique()
print(f"Number of unique Outlet_Identifiers: {num_unique_outlets}")

plt.figure(figsize=(10, 6))
sns.countplot(x='Outlet_Identifier', data=df, palette='Dark2')
plt.title('Distribution of Outlet Identifiers')
plt.xlabel('Outlet Identifier')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# Number of unique Outlet_Identifiers: 10
# /tmp/ipykernel_4591/1160762081.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outlet_Identifier', data=df, palette='Dark2')

# %% [markdown]
# ### Outlet_Establishment_Year

# %% [markdown]
# Definition: The year in which store was established

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Outlet_Establishment_Year', data=df, palette='coolwarm')
plt.title('Distribution of Outlet Establishment Year')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/2591332611.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outlet_Establishment_Year', data=df, palette='coolwarm')

# %% [markdown]
# ### Outlet_Size

# %% [markdown]
# Definition: The size of the store in terms of ground area

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Outlet_Size', data=df, palette='plasma')
plt.title('Distribution of Outlet Size')
plt.xlabel('Outlet Size')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_4591/3486760978.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outlet_Size', data=df, palette='plasma')

# %% [markdown]
# ### Outlet_Location_Type

# %% [markdown]
# Definition: The type of city in which the store is located

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Outlet_Location_Type', data=df, palette='viridis')
plt.title('Distribution of Outlet Location Type')
plt.xlabel('Outlet Location Type')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_4591/2670784478.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outlet_Location_Type', data=df, palette='viridis')

# %% [markdown]
# ### Outlet_Type

# %% [markdown]
# Definition: Whether the store is a grocery store or some type of supermarket

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x='Outlet_Type', data=df, palette='rocket')
plt.title('Distribution of Outlet Type')
plt.xlabel('Outlet Type')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_4591/3225183365.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outlet_Type', data=df, palette='rocket')

# %% [markdown]
# ### Item_Outlet_Sales

# %% [markdown]
# Definition: Sales of the product in a particular store. This is the target variable.

# %% [markdown]
# ### Outlet_Type

# %% [markdown]
# Definition: Whether the store is a grocery store or some type of supermarket

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x='Outlet_Type', data=df, palette='rocket')
plt.title('Distribution of Outlet Type')
plt.xlabel('Outlet Type')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_4591/3225183365.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outlet_Type', data=df, palette='rocket')

# %% [markdown]
# ### Item_Outlet_Sales

# %% [markdown]
# Definition: Sales of the product in a particular store. This is the target variable.

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Item_Outlet_Sales'], kde=True, bins=30)
plt.title('Distribution of Item Outlet Sales (Target Variable)')
plt.xlabel('Item Outlet Sales')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Item_Outlet_Sales'], kde=True, bins=30)
plt.title('Distribution of Item Outlet Sales (Target Variable)')
plt.xlabel('Item Outlet Sales')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Item_Visibility'], kde=True, bins=30)
plt.title('Distribution of Item Visibility')
plt.xlabel('Item Visibility')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Feature Inspection Summary
#
# ### Item_Identifier
# *   **Type**: Categorical (nominal)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, there are 1559 unique identifiers.
# *   **Cardinality**: 1559. This is very high.
# *   **Known before target**: Yes, product IDs are known before sales are determined.
# *   **Business case exclusion**: No, this is a crucial identifier. However, given its high cardinality, it might be better used for grouping or extracting information rather than direct encoding for modeling.
#
# ### Item_Weight
# *   **Type**: Numeric (continuous)
# *   **Null Values**: After the previous cleaning, there are still null values which should be checked by running `df['Item_Weight'].isnull().sum()` and `df['Item_Weight'].isnull().sum() / len(df) * 100`. Assuming there are some, imputation would be the best approach. Possible imputation methods include the mean, median, or a more sophisticated method like K-Nearest Neighbors imputation, or group-wise imputation (e.g., impute by `Item_Type`).
# *   **Constant/Quasi-constant**: No, it has a wide range of values.
# *   **Cardinality**: Based on the histogram, it seems to have many unique values, indicating good variability.
# *   **Known before target**: Yes, product weights are known before sales.
# *   **Business case exclusion**: No, weight can be a significant factor in sales.
#
# ### Item_Fat_Content
# *   **Type**: Categorical (nominal)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, it has different categories.
# *   **Cardinality**: Few unique values (e.g., 'Low Fat', 'Regular', 'low fat', 'reg', 'LF'). These should be mapped to consistent values (e.g., 'Low Fat', 'Regular') during data cleaning.
# *   **Known before target**: Yes, fat content is a product attribute.
# *   **Business case exclusion**: No, fat content can influence customer choices.
#
# ### Item_Visibility
# *   **Type**: Numeric (continuous)
# *   **Null Values**: 0 null values (0%). No action needed. However, the `0.0` values (observed in the histogram) might represent missing visibility data that was imputed to 0, which could be treated as null or handled specifically. If they represent actual 0 visibility, they are valid.
# *   **Constant/Quasi-constant**: No, it shows a distribution of values.
# *   **Cardinality**: High, as it's a continuous variable.
# *   **Known before target**: Yes, visibility is set before sales.
# *   **Business case exclusion**: No, visibility is a direct driver of sales.
#
# ### Item_Type
# *   **Type**: Categorical (nominal)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, it has many distinct categories.
# *   **Cardinality**: 16 unique categories. This is moderate cardinality and suitable for one-hot encoding or other categorical encoding methods.
# *   **Known before target**: Yes, item type is a product attribute.
# *   **Business case exclusion**: No, item type is a fundamental characteristic of a product that affects sales.
#
# ### Item_MRP
# *   **Type**: Numeric (continuous)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, it has a wide range of prices.
# *   **Cardinality**: High, as it's a continuous variable.
# *   **Known before target**: Yes, MRP is set before sales.
# *   **Business case exclusion**: No, price is a very strong predictor of sales.
#
# ### Outlet_Identifier
# *   **Type**: Categorical (nominal)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, there are 10 unique identifiers.
# *   **Cardinality**: 10 unique identifiers. This is low cardinality and ideal for one-hot encoding.
# *   **Known before target**: Yes, store IDs are known.
# *   **Business case exclusion**: No, each outlet likely has unique sales patterns and characteristics.
#
# ### Outlet_Establishment_Year
# *   **Type**: Numeric (discrete) or Categorical (ordinal if treated as age/vintage)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, there are several distinct establishment years.
# *   **Cardinality**: Few unique years, indicating low cardinality.
# *   **Known before target**: Yes, establishment year is a fixed store attribute.
# *   **Business case exclusion**: No, the age of an outlet can impact sales.
#
# ### Outlet_Size
# *   **Type**: Categorical (ordinal - Small, Medium, High)
# *   **Null Values**: Likely has null values from replacing 'Missing' placeholders. If nulls exist, imputation with the mode is a common strategy for categorical data. Alternatively, a separate category for 'Unknown' or 'Missing' could be created.
# *   **Constant/Quasi-constant**: No, it has distinct sizes.
# *   **Cardinality**: 3 unique categories (excluding nulls). Low cardinality.
# *   **Known before target**: Yes, outlet size is a fixed store attribute.
# *   **Business case exclusion**: No, larger stores might have higher sales volumes.
#
# ### Outlet_Location_Type
# *   **Type**: Categorical (nominal - Tier 1, Tier 2, Tier 3)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, it has distinct tiers.
# *   **Cardinality**: 3 unique categories. Low cardinality.
# *   **Known before target**: Yes, location type is a fixed store attribute.
# *   **Business case exclusion**: No, location tier is a strong indicator of customer demographics and sales potential.
#
# ### Outlet_Type
# *   **Type**: Categorical (nominal)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, it has distinct types.
# *   **Cardinality**: 4 unique categories. Low cardinality.
# *   **Known before target**: Yes, outlet type is a fixed store attribute.
# *   **Business case exclusion**: No, the type of store (e.g., grocery store vs. supermarket) significantly impacts sales.
#
# ### Item_Outlet_Sales (Target Variable)
# *   **Type**: Numeric (continuous)
# *   **Null Values**: 0 null values (0%). No action needed.
# *   **Constant/Quasi-constant**: No, it has a wide range of values.
# *   **Cardinality**: High, as it's a continuous variable.
# *   **Known before target**: No, this is the variable we are trying to predict.
# *   **Business case exclusion**: No, this is our target variable.

# %% [markdown]
# ## Multivariate Visualizations: Features vs. Item_Outlet_Sales

# %% [markdown]
# ### Item_Weight vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Item_Weight', y='Item_Outlet_Sales', data=df, alpha=0.5)
plt.title('Item Weight vs. Item Outlet Sales')
plt.xlabel('Item Weight')
plt.ylabel('Item Outlet Sales')
plt.show()

# %% [markdown]
# ### Item_Visibility vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Item_Visibility', y='Item_Outlet_Sales', data=df, alpha=0.5)
plt.title('Item Visibility vs. Item Outlet Sales')
plt.xlabel('Item Visibility')
plt.ylabel('Item Outlet Sales')
plt.show()

# %% [markdown]
# ### Item_MRP vs. Item_Outlet_Sales

# %% [markdown]
# ### Item_Fat_Content vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', data=df, palette='viridis')
plt.title('Item Fat Content vs. Item Outlet Sales')
plt.xlabel('Item Fat Content')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/2350811519.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', data=df, palette='viridis')

# %% [markdown]
# ### Item_Type vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Item_Type', y='Item_Outlet_Sales', data=df, palette='Spectral')
plt.title('Item Type vs. Item Outlet Sales')
plt.xlabel('Item Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/265642380.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item_Type', y='Item_Outlet_Sales', data=df, palette='Spectral')

# %% [markdown]
# ### Outlet_Identifier vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df, palette='Dark2')
plt.title('Outlet Identifier vs. Item Outlet Sales')
plt.xlabel('Outlet Identifier')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/389525525.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df, palette='Dark2')

# %% [markdown]
# ### Outlet_Establishment_Year vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, palette='coolwarm')
plt.title('Outlet Establishment Year vs. Item Outlet Sales')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3436251788.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, palette='coolwarm')

# %% [markdown]
# ### Outlet_Size vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='plasma')
plt.title('Outlet Size vs. Item Outlet Sales')
plt.xlabel('Outlet Size')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/1940371947.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='plasma')

# %% [markdown]
# ### Outlet_Location_Type vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Outlet_Location_Type', y='Item_Outlet_Sales', data=df, palette='viridis')
plt.title('Outlet Location Type vs. Item Outlet Sales')
plt.xlabel('Outlet Location Type')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/4024555280.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Location_Type', y='Item_Outlet_Sales', data=df, palette='viridis')

# %% [markdown]
# ### Outlet_Type vs. Item_Outlet_Sales

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df, palette='rocket')
plt.title('Outlet Type vs. Item Outlet Sales')
plt.xlabel('Outlet Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/2038555660.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df, palette='rocket')

# %% [markdown]
# ### Item_Fat_Content vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', data=df, palette='viridis')
plt.title('Item Fat Content vs. Item Outlet Sales')
plt.xlabel('Item Fat Content')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/3753102313.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', data=df, palette='viridis')

# %% [markdown]
# ### Item_Type vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))
sns.boxplot(x='Item_Type', y='Item_Outlet_Sales', data=df, palette='Spectral')
plt.title('Item Type vs. Item Outlet Sales')
plt.xlabel('Item Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3460725105.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item_Type', y='Item_Outlet_Sales', data=df, palette='Spectral')

# %% [markdown]
# ### Outlet_Identifier vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df, palette='Dark2')
plt.title('Outlet Identifier vs. Item Outlet Sales')
plt.xlabel('Outlet Identifier')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3585408750.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df, palette='Dark2')

# %% [markdown]
# ### Outlet_Establishment_Year vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, palette='coolwarm')
plt.title('Outlet Establishment Year vs. Item Outlet Sales')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3741788245.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, palette='coolwarm')

# %% [markdown]
# ### Outlet_Size vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='plasma')
plt.title('Outlet Size vs. Item Outlet Sales')
plt.xlabel('Outlet Size')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/2160359339.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='plasma')

# %% [markdown]
# ### Outlet_Location_Type vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(x='Outlet_Location_Type', y='Item_Outlet_Sales', data=df, palette='viridis')
plt.title('Outlet Location Type vs. Item Outlet Sales')
plt.xlabel('Outlet Location Type')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/2788570650.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Location_Type', y='Item_Outlet_Sales', data=df, palette='viridis')

# %% [markdown]
# ### Outlet_Type vs. Item_Outlet_Sales

# %%
import pandas as pd
file_path = '/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_cleaned.csv'
df = pd.read_csv(file_path)
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df, palette='rocket')
plt.title('Outlet Type vs. Item Outlet Sales')
plt.xlabel('Outlet Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/350895952.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df, palette='rocket')

# %% [markdown]
# ### Item_Fat_Content vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', data=df, palette='viridis')
plt.title('Item Fat Content vs. Item Outlet Sales')
plt.xlabel('Item Fat Content')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/2454552395.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item_Fat_Content', y='Item_Outlet_Sales', data=df, palette='viridis')

# %% [markdown]
# ### Item_Type vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 7))
sns.boxplot(x='Item_Type', y='Item_Outlet_Sales', data=df, palette='Spectral')
plt.title('Item Type vs. Item Outlet Sales')
plt.xlabel('Item Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3680421339.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Item_Type', y='Item_Outlet_Sales', data=df, palette='Spectral')

# %% [markdown]
# ### Outlet_Identifier vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df, palette='Dark2')
plt.title('Outlet Identifier vs. Item Outlet Sales')
plt.xlabel('Outlet Identifier')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3762086652.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df, palette='Dark2')

# %% [markdown]
# ### Outlet_Establishment_Year vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, palette='coolwarm')
plt.title('Outlet Establishment Year vs. Item Outlet Sales')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/4175264247.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Establishment_Year', y='Item_Outlet_Sales', data=df, palette='coolwarm')

# %% [markdown]
# ### Outlet_Size vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='plasma')
plt.title('Outlet Size vs. Item Outlet Sales')
plt.xlabel('Outlet Size')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/3396648482.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='plasma')

# %% [markdown]
# ### Outlet_Location_Type vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(x='Outlet_Location_Type', y='Item_Outlet_Sales', data=df, palette='viridis')
plt.title('Outlet Location Type vs. Item Outlet Sales')
plt.xlabel('Outlet Location Type')
plt.ylabel('Item Outlet Sales')
plt.show()
# Out:
# /tmp/ipykernel_4591/3302780317.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Location_Type', y='Item_Outlet_Sales', data=df, palette='viridis')

# %% [markdown]
# ### Outlet_Type vs. Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df, palette='rocket')
plt.title('Outlet Type vs. Item Outlet Sales')
plt.xlabel('Outlet Type')
plt.ylabel('Item Outlet Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4591/3751382387.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df, palette='rocket')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Item_MRP', y='Item_Outlet_Sales', data=df, alpha=0.5)
plt.title('Item MRP vs. Item Outlet Sales')
plt.xlabel('Item MRP')
plt.ylabel('Item Outlet Sales')
plt.show()

# %% [markdown]
# ## Feature Predictor Summary
#
# ### Item_Identifier
# *   **Expected predictor (business understanding)**: Yes, different products will naturally have different sales patterns.
# *   **Appears to be a predictor**: Yes, the unique IDs differentiate products, which will have varying sales (though direct visualization is not feasible due to high cardinality).
#
# ### Item_Weight
# *   **Expected predictor (business understanding)**: Possibly, weight could correlate with product size or bulk, which might affect sales.
# *   **Appears to be a predictor**: Not strongly based on the scatter plot. Sales values are spread across all weight ranges without a clear trend.
#
# ### Item_Fat_Content
# *   **Expected predictor (business understanding)**: Yes, consumer preferences for fat content can impact sales.
# *   **Appears to be a predictor**: Yes, the box plot shows some differences in sales distribution between 'Low Fat' and 'Regular' items, with 'Regular' having slightly higher median sales.
#
# ### Item_Visibility
# *   **Expected predictor (business understanding)**: Yes, higher visibility should lead to higher sales.
# *   **Appears to be a predictor**: Not strongly linearly. The scatter plot shows sales across all visibility values, but higher sales tend to be associated with moderate visibility, while very low visibility values can also have a wide range of sales. The zero-visibility values need special attention.
#
# ### Item_Type
# *   **Expected predictor (business understanding)**: Yes, different product types will have different demand and sales.
# *   **Appears to be a predictor**: Yes, the box plot clearly shows variations in sales distributions across different item types, indicating it is a good predictor.
#
# ### Item_MRP
# *   **Expected predictor (business understanding)**: Yes, price is a primary driver of sales.
# *   **Appears to be a predictor**: Yes, the scatter plot shows a strong positive correlation, with higher MRP generally corresponding to higher sales.
#
# ### Outlet_Identifier
# *   **Expected predictor (business understanding)**: Yes, each store has unique characteristics that affect its sales.
# *   **Appears to be a predictor**: Yes, the box plot shows significant differences in sales distributions across different outlets, making it a strong predictor.
#
# ### Outlet_Establishment_Year
# *   **Expected predictor (business understanding)**: Yes, older or newer stores might have different customer bases or operational models affecting sales.
# *   **Appears to be a predictor**: Yes, the box plot indicates variations in sales based on the establishment year, suggesting it is a predictor.
#
# ### Outlet_Size
# *   **Expected predictor (business understanding)**: Yes, larger stores typically handle more inventory and customer traffic, leading to higher sales.
# *   **Appears to be a predictor**: Yes, the box plot shows 'High' and 'Medium' sized outlets tend to have higher sales than 'Small' outlets, confirming its predictive power.
#
# ### Outlet_Location_Type
# *   **Expected predictor (business understanding)**: Yes, different location types (e.g., urban vs. rural) will attract different customer volumes and demographics, influencing sales.
# *   **Appears to be a predictor**: Yes, the box plot shows differences in sales across location types, with 'Tier 3' locations generally having higher median sales.
#
# ### Outlet_Type
# *   **Expected predictor (business understanding)**: Yes, the type of store (e.g., supermarket vs. grocery store) directly influences product offerings, customer base, and sales volume.
# *   **Appears to be a predictor**: Yes, the box plot shows substantial differences in sales across different outlet types, especially 'Supermarket Type3' having significantly higher sales.
#
# ### Item_Outlet_Sales (Target Variable)
# *   **Expected predictor (business understanding)**: N/A (this is the target).
# *   **Appears to be a predictor**: N/A (this is the target).
